# %%
import pandas as pd
import numpy as np
import os

# %%
path=r"C:\Users\galia\Instacart Basket Analysis"

# %%
path
# Out:
# 'C:\\Users\\galia\\Instacart Basket Analysis'

# %%
#import orderschecked
df_ords=pd.read_csv(os.path.join(path,"02 Data","Prepared Data","order_checked.csv"))

# %%
#import new data set orders prior
df_ords_prior=pd.read_csv(os.path.join(path,"02 Data","Original Data","order_products__prior.csv"))

# %%
#check ords prior
df_ords_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
#check ords
df_ords.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0             0           0   2539329        1             1
# 1             1           1   2398795        1             2
# 2             2           2    473747        1             3
# 3             3           3   2254736        1             4
# 4             4           4    431534        1             5
#
#    orders_days_of_the_week  time_of_day  days_since_prior_order
# 0                        2            8                     NaN
# 1                        3            7                    15.0
# 2                        3           12                    21.0
# 3                        4            7                    29.0
# 4                        4           15                    28.0

# %%
df_ords.shape
# Out:
# (3421083, 8)

# %%
df_ords_prior.shape
# Out:
# (32434489, 4)

# %%
#merge the data frames
df_merged_large = df_ords.merge(df_ords_prior, on = 'order_id', indicator = True)

# %%
df_merged_large.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0             0           0   2539329        1             1
# 1             0           0   2539329        1             1
# 2             0           0   2539329        1             1
# 3             0           0   2539329        1             1
# 4             0           0   2539329        1             1
#
#    orders_days_of_the_week  time_of_day  days_since_prior_order  product_id  \
# 0                        2            8                     NaN         196
# 1                        2            8                     NaN       14084
# 2                        2            8                     NaN       12427
# 3                        2            8                     NaN       26088
# 4                        2            8                     NaN       26405
#
#    add_to_cart_order  reordered _merge
# 0                  1          0   both
# 1                  2          0   both
# ...

# %%
df_merged_large["_merge"].value_counts()
# Out:
# both          32434489
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
#exporting data as pickle
df_merged_large.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_combined.pkl'))

# %%
#exporting data as csv
df_merged_large.to_csv(os.path.join(path, '02 Data','Prepared Data', 'orders_products_combined.csv'))

# %% [markdown]
# ##Task

# %%
#import combined data
df_ords_comb=pd.read_pickle(os.path.join(path,"02 Data","Prepared Data","orders_products_combined.pkl"))

# %%
#checking shape
df_ords_comb.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0             0           0   2539329        1             1
# 1             0           0   2539329        1             1
# 2             0           0   2539329        1             1
# 3             0           0   2539329        1             1
# 4             0           0   2539329        1             1
#
#    orders_days_of_the_week  time_of_day  days_since_prior_order  product_id  \
# 0                        2            8                     NaN         196
# 1                        2            8                     NaN       14084
# 2                        2            8                     NaN       12427
# 3                        2            8                     NaN       26088
# 4                        2            8                     NaN       26405
#
#    add_to_cart_order  reordered _merge
# 0                  1          0   both
# 1                  2          0   both
# ...

# %%
df_ords_comb.shape
# Out:
# (32434489, 12)

# %%
#import products
df_prods=pd.read_csv(os.path.join(path,"02 Data","Prepared Data","products_checked.csv"))

# %%
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
# Drop '_merge' column for df_orders_products_combined
df_ords_comb = df_ords_comb.drop(columns = ['_merge'])

# %%
#merge of df using product id
orders_products_merged=df_ords_comb.merge(df_prods, on = "product_id",indicator = True)

# %%
#checking the merge
orders_products_merged['_merge'].value_counts()
# Out:
# both          32404859
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
#exporting
orders_products_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged.pkl'))

# %%
orders_products_merged.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0             0             0   2539329        1             1
# 1             1             1   2398795        1             2
# 2             2             2    473747        1             3
# 3             3             3   2254736        1             4
# 4             4             4    431534        1             5
#
#    orders_days_of_the_week  time_of_day  days_since_prior_order  product_id  \
# 0                        2            8                     NaN         196
# 1                        3            7                    15.0         196
# 2                        3           12                    21.0         196
# 3                        4            7                    29.0         196
# 4                        4           15                    28.0         196
#
#    add_to_cart_order  reordered  Unnamed: 0_y product_name  aisle_id  \
# ...

# %%
orders_products_merged
# Out:
#           Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0                    0             0   2539329        1             1
# 1                    1             1   2398795        1             2
# 2                    2             2    473747        1             3
# 3                    3             3   2254736        1             4
# 4                    4             4    431534        1             5
# ...                ...           ...       ...      ...           ...
# 32404854       3360493       3360493   1320836   202557            17
# 32404855       3360494       3360494     31526   202557            18
# 32404856       3376038       3376038    758936   203436             1
# 32404857       3376039       3376039   2745165   203436             2
# 32404858       3408036       3408036   3093936   205420             1
#
#           orders_days_of_the_week  time_of_day  days_since_prior_order  \
# ...

# %%
orders_products_merged.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0             0             0   2539329        1             1
# 1             1             1   2398795        1             2
# 2             2             2    473747        1             3
# 3             3             3   2254736        1             4
# 4             4             4    431534        1             5
#
#    orders_days_of_the_week  time_of_day  days_since_prior_order  product_id  \
# 0                        2            8                     NaN         196
# 1                        3            7                    15.0         196
# 2                        3           12                    21.0         196
# 3                        4            7                    29.0         196
# 4                        4           15                    28.0         196
#
#    add_to_cart_order  reordered  Unnamed: 0_y product_name  aisle_id  \
# ...
