# %%
import pandas as pd
import numpy as np
import os

# %%
path=r"C:\Users\galia\Instacart Basket Analysis\02 Data\Prepared Data"

# %%
# importing dataframe
ords_prods_merge=pd.read_pickle(os.path.join(path,"orders_products_merged.pkl"))

# %%
#creating subset
df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 21)

# %%
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0             0             0   2539329        1             1
# 1             1             1   2398795        1             2
# 2             2             2    473747        1             3
# 3             3             3   2254736        1             4
# 4             4             4    431534        1             5
#
#    orders_days_of_the_week  time_of_day  days_since_prior_order  product_id  \
# 0                        2            8                     NaN         196
# 1                        3            7                    15.0         196
# 2                        3           12                    21.0         196
# 3                        4            7                    29.0         196
# 4                        4           15                    28.0         196
#
#    add_to_cart_order  ...  Unnamed: 0_y  product_name aisle_id  department_id  \
# 0                  1  ...           195          Soda       77              7
# 1                  1  ...           195          Soda       77              7
# 2                  1  ...           195          Soda       77              7
# 3                  1  ...           195          Soda       77              7
# 4                  1  ...           195          Soda       77              7
#
#    prices  _merge    price_range_loc     busiest_day    busiest_days  \
# 0     9.0    both  Mid-range product  Regularly busy  Regularly busy
# 1     9.0    both  Mid-range product  Regularly busy      Least busy
# 2     9.0    both  Mid-range product  Regularly busy      Least busy
# 3     9.0    both  Mid-range product      Least busy      Least busy
# 4     9.0    both  Mid-range product      Least busy      Least busy
#
#   busiest_period_of_day
# 0        Average orders
# 1        Average orders
# 2           Most orders
# 3        Average orders
# 4           Most orders
#
# [5 rows x 21 columns]

# %%
#grouping by product name
df.groupby("product_name")

# %%
#performing aggregation
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4                18.825780
# 7                17.472355
# 13               17.993423
# 14               19.246334
# 16               19.463012
# 17               11.294069
# 19               19.305237
# 20               17.599636

# %%
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 4     18.825780
# 7     17.472355
# 13    17.993423
# 14    19.246334
# 16    19.463012
# 17    11.294069
# 19    19.305237
# 20    17.599636
# Name: order_number, dtype: float64

# %%
#Performing Multiple Aggregations
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 4                18.825780   1  99
# 7                17.472355   1  99
# 13               17.993423   1  99
# 14               19.246334   1  99
# 16               19.463012   1  99
# 17               11.294069   1  98
# 19               19.305237   1  99
# 20               17.599636   1  99

# %%
#Aggregating Data with transform()
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head(20)
# Out:
#     Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0              0             0   2539329        1             1
# 1              1             1   2398795        1             2
# 2              2             2    473747        1             3
# 3              3             3   2254736        1             4
# 4              4             4    431534        1             5
# 5              5             5   3367565        1             6
# 6              6             6    550135        1             7
# 7              7             7   3108588        1             8
# 8              8             8   2295261        1             9
# 9              9             9   2550362        1            10
# 10           144           144   2968173       15            15
# 11           146           146   1870022       15            17
# 12           147           147   1911383       15            18
# 13           150           150   2715276       15            21
# 14           151           151    487368       15            22
# 15           209           209   2293453       19             2
# 16           212           212   1973799       19             5
# 17           214           214    532817       19             7
# 18           232           232   1573906       21            10
# 19           458           458   1593000       31            10
#
#     orders_days_of_the_week  time_of_day  days_since_prior_order  product_id  \
# 0                         2            8                     NaN         196
# 1                         3            7                    15.0         196
# 2                         3           12                    21.0         196
# 3                         4            7                    29.0         196
# 4                         4           15                    28.0         196
# 5                         2            7                    19.0         196
# 6                         1            9                    20.0         196
# 7                         1           14                    14.0         196
# 8                         1           16                     0.0         196
# 9                         4            8                    30.0         196
# 10                        1            9                     7.0         196
# 11                        2           16                     8.0         196
# 12                        2           11                     7.0         196
# 13                        1            9                     7.0         196
# 14                        1           10                    14.0         196
# 15                        5           14                     6.0         196
# 16                        6           12                     8.0         196
# 17                        4           17                     6.0         196
# 18                        3           10                     6.0         196
# 19                        3            8                     7.0         196
#
#     add_to_cart_order  ...  product_name  aisle_id department_id  prices  \
# 0                   1  ...          Soda        77             7     9.0
# 1                   1  ...          Soda        77             7     9.0
# 2                   1  ...          Soda        77             7     9.0
# 3                   1  ...          Soda        77             7     9.0
# 4                   1  ...          Soda        77             7     9.0
# 5                   1  ...          Soda        77             7     9.0
# 6                   1  ...          Soda        77             7     9.0
# 7                   2  ...          Soda        77             7     9.0
# 8                   4  ...          Soda        77             7     9.0
# 9                   1  ...          Soda        77             7     9.0
# 10                  2  ...          Soda        77             7     9.0
# 11                  6  ...          Soda        77             7     9.0
# 12                  1  ...          Soda        77             7     9.0
# 13                  1  ...          Soda        77             7     9.0
# 14                  1  ...          Soda        77             7     9.0
# 15                  3  ...          Soda        77             7     9.0
# 16                 15  ...          Soda        77             7     9.0
# 17                  1  ...          Soda        77             7     9.0
# 18                  2  ...          Soda        77             7     9.0
# 19                 17  ...          Soda        77             7     9.0
#
#     _merge    price_range_loc     busiest_day    busiest_days  \
# 0     both  Mid-range product  Regularly busy  Regularly busy
# 1     both  Mid-range product  Regularly busy      Least busy
# 2     both  Mid-range product  Regularly busy      Least busy
# 3     both  Mid-range product      Least busy      Least busy
# 4     both  Mid-range product      Least busy      Least busy
# 5     both  Mid-range product  Regularly busy  Regularly busy
# 6     both  Mid-range product  Regularly busy     Busiest day
# 7     both  Mid-range product  Regularly busy     Busiest day
# 8     both  Mid-range product  Regularly busy     Busiest day
# 9     both  Mid-range product      Least busy      Least busy
# 10    both  Mid-range product  Regularly busy     Busiest day
# 11    both  Mid-range product  Regularly busy  Regularly busy
# 12    both  Mid-range product  Regularly busy  Regularly busy
# 13    both  Mid-range product  Regularly busy     Busiest day
# 14    both  Mid-range product  Regularly busy     Busiest day
# 15    both  Mid-range product  Regularly busy  Regularly busy
# 16    both  Mid-range product  Regularly busy  Regularly busy
# 17    both  Mid-range product      Least busy      Least busy
# 18    both  Mid-range product  Regularly busy      Least busy
# 19    both  Mid-range product  Regularly busy      Least busy
#
#    busiest_period_of_day max_order
# 0         Average orders        10
# 1         Average orders        10
# 2            Most orders        10
# 3         Average orders        10
# 4            Most orders        10
# 5         Average orders        10
# 6            Most orders        10
# 7            Most orders        10
# 8            Most orders        10
# 9         Average orders        10
# 10           Most orders        22
# 11           Most orders        22
# 12           Most orders        22
# 13           Most orders        22
# 14           Most orders        22
# 15           Most orders         9
# 16           Most orders         9
# 17        Average orders         9
# 18           Most orders        33
# 19        Average orders        20
#
# [20 rows x 22 columns]

# %%
pd.options.display.max_rows = None

# %%
#creating loyalty flag
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna=False)
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: loyalty_flag, dtype: int64

# %%
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             2
# 2         1      New customer             3
# 3         1      New customer             4
# 4         1      New customer             5
# 5         1      New customer             6
# 6         1      New customer             7
# 7         1      New customer             8
# 8         1      New customer             9
# 9         1      New customer            10
# 10       15  Regular customer            15
# 11       15  Regular customer            17
# 12       15  Regular customer            18
# 13       15  Regular customer            21
# 14       15  Regular customer            22
# 15       19      New customer             2
# 16       19      New customer             5
# 17       19      New customer             7
# 18       21  Regular customer            10
# 19       31  Regular customer            10
# 20       31  Regular customer            17
# 21       43  Regular customer             6
# 22       43  Regular customer             9
# 23       52  Regular customer             1
# 24       52  Regular customer             2
# 25       52  Regular customer             3
# 26       52  Regular customer             5
# 27       52  Regular customer             7
# 28       52  Regular customer             9
# 29       52  Regular customer            10
# 30       52  Regular customer            11
# 31       52  Regular customer            12
# 32       52  Regular customer            15
# 33       52  Regular customer            17
# 34       52  Regular customer            18
# 35       52  Regular customer            19
# 36       52  Regular customer            21
# 37       67  Regular customer             1
# 38       67  Regular customer             2
# 39       67  Regular customer             3
# 40       67  Regular customer             4
# 41       67  Regular customer             5
# 42       67  Regular customer             6
# 43       67  Regular customer             8
# 44       67  Regular customer             9
# 45       67  Regular customer            10
# 46       67  Regular customer            11
# 47       67  Regular customer            12
# 48       67  Regular customer            13
# 49       67  Regular customer            14
# 50       67  Regular customer            16
# 51       67  Regular customer            18
# 52       67  Regular customer            19
# 53       67  Regular customer            21
# 54       67  Regular customer            22
# 55       67  Regular customer            23
# 56       81      New customer             3
# 57       81      New customer             5
# 58       82  Regular customer             1
# 59       82  Regular customer             3

# %%
ords_prods_merge.to_pickle(os.path.join(path, 'orders_products_merged.pkl'))
